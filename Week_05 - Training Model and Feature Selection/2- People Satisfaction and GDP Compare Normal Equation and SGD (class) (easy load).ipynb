# %% [markdown]
# <a href="https://colab.research.google.com/github/saeid-uot/3253-Machine-Learning/blob/main/Week_05%20-%20Training%20Model%20and%20Feature%20Selection/2-%20People%20Satisfaction%20and%20GDP%20Compare%20Normal%20Equation%20and%20SGD%20(class)%20(easy%20load).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Predict People Satisfaction Across the Globe
#
# Problem Statement:
#
# We would like to build a model that predicts satisfaction score for people of different countries given their country GDP.

# %% [markdown]
# # Download Dataset
#
# Download the Better Life Index data (latest edition, currently it is 2017) from the [OECD’s website](http://homl.info/4) as well as stats about GDP per capita from the [IMF’s website](http://homl.info/5). Then you join the tables and sort by GDP per capita. Table 1-1 shows an excerpt of what you get

# %%
# !pip install googledrivedownloader
# Out:
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.12/dist-packages (1.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from googledrivedownloader) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->googledrivedownloader) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->googledrivedownloader) (3.15)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->googledrivedownloader) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->googledrivedownloader) (2026.5.20)

# %%
#get file from google drive
# %%time
import sys

from googledrivedownloader import download_file_from_google_drive

download_file_from_google_drive(file_id="1AavEtw38uMBhcDLmejYU_L8LVbbrWtlh",
                                    dest_path="./BLI_30012019054825599.xlsx",
                                    unzip=False)

download_file_from_google_drive(file_id="1Z0hri7DaH37aH-VGmyC5G2Uo240NfFms",
                                    dest_path="./WEO_Data.xlsx",
                                    unzip=False)
# Out:
# Downloading 1AavEtw38uMBhcDLmejYU_L8LVbbrWtlh into ./BLI_30012019054825599.xlsx... Done.
# Downloading 1Z0hri7DaH37aH-VGmyC5G2Uo240NfFms into ./WEO_Data.xlsx... Done.
# CPU times: user 36.2 ms, sys: 3.69 ms, total: 39.9 ms
# Wall time: 2.48 s

# %% [markdown]
# # Load data as dataframes

# %%
import pandas as pd
from IPython.display import display

# %%
#load excel as dataframe
bli = pd.read_excel("BLI_30012019054825599.xlsx", sheet_name=0)

display(bli) #inspect if the dataframe is loaded correctly

# Remove rows where inequality has values other than TOT
bli = bli[bli["INEQUALITY"]=="TOT"]

# Reformat data based on "indicator column"
bli = bli.pivot(index="Country", columns="Indicator", values="Value")

bli["Life satisfaction"].head()
# Out:
#      LOCATION        Country  INDICATOR  \
# 0         AUS      Australia    JE_LMIS
# 1         AUS      Australia    CG_SENG
# 2         AUS      Australia    CG_SENG
# 3         AUS      Australia    CG_SENG
# 4         AUS      Australia  PS_FSAFEN
# ...       ...            ...        ...
# 3394      USA  United States    WL_EWLH
# 3395      USA  United States    WL_TNOW
# 3396      USA  United States    WL_TNOW
# 3397      USA  United States    WL_TNOW
# 3398      NaN            NaN        NaN
#
#                                               Indicator MEASURE Measure  \
# 0                              Labour market insecurity       L   Value
# 1     Stakeholder engagement for developing regulations       L   Value
# 2     Stakeholder engagement for developing regulations       L   Value
# 3     Stakeholder engagement for developing regulations       L   Value
# 4                   Feeling safe walking alone at night       L   Value
# ...                                                 ...     ...     ...
# 3394                  Employees working very long hours       L   Value
# 3395          Time devoted to leisure and personal care       L   Value
# 3396          Time devoted to leisure and personal care       L   Value
# 3397          Time devoted to leisure and personal care       L   Value
# 3398                                                NaN     NaN     NaN
#
#      INEQUALITY Inequality Unit Code           Unit  PowerCode Code PowerCode  \
# 0           TOT      Total        PC     Percentage             0.0     Units
# 1           TOT      Total   AVSCORE  Average score             0.0     Units
# 2            MN        Men   AVSCORE  Average score             0.0     Units
# 3           WMN      Women   AVSCORE  Average score             0.0     Units
# 4           TOT      Total        PC     Percentage             0.0     Units
# ...         ...        ...       ...            ...             ...       ...
# 3394        WMN      Women        PC     Percentage             0.0     Units
# 3395        TOT      Total      HOUR          Hours             0.0     Units
# 3396         MN        Men      HOUR          Hours             0.0     Units
# 3397        WMN      Women      HOUR          Hours             0.0     Units
# 3398        NaN        NaN       NaN            NaN             NaN       NaN
#
#       Reference Period Code  Reference Period        Value Flag Codes  \
# 0                       NaN               NaN     4.300000        NaN
# 1                       NaN               NaN     2.700000        NaN
# 2                       NaN               NaN     2.700000          E
# 3                       NaN               NaN     2.700000          E
# 4                       NaN               NaN    63.600000        NaN
# ...                     ...               ...          ...        ...
# 3394                    NaN               NaN     6.860000        NaN
# 3395                    NaN               NaN    14.440000        NaN
# 3396                    NaN               NaN    14.480000        NaN
# 3397                    NaN               NaN    14.390000        NaN
# 3398                    NaN               NaN  7152.398471        NaN
#
#                 Flags
# 0                 NaN
# 1                 NaN
# 2     Estimated value
# 3     Estimated value
# 4                 NaN
# ...               ...
# 3394              NaN
# 3395              NaN
# 3396              NaN
# 3397              NaN
# 3398              NaN
#
# [3399 rows x 17 columns]
# Country
# Australia    7.3
# Austria      7.0
# Belgium      6.9
# Brazil       6.6
# Canada       7.3
# Name: Life satisfaction, dtype: float64

# %% [markdown]
# # Import WOE data

# %%
#load excel as dataframe
weo = pd.read_excel("WEO_Data.xlsx", sheet_name=0)
display(weo) #inspect if the dataframe is loaded correctly

# Drop the header row from data
weo = weo.reindex(weo.index.drop(0))

# 1- Select only Country name and 2015
# 2- then rename it to GDP Per capita
weo = weo[['Country','2015']].rename(columns={'2015':'GDP per capita'})

# Set Country as index column
# Inplace command, will replace the results of command into the same DF
weo.set_index("Country", inplace=True)

#weo.drop_duplicates(inplace=True)
#Print top 5 rows
weo.head()
# Out:
#                                                Country  \
# 0                                          Afghanistan
# 1                                              Albania
# 2                                              Algeria
# 3                                               Angola
# 4                                  Antigua and Barbuda
# ..                                                 ...
# 186                                              Yemen
# 187                                             Zambia
# 188                                           Zimbabwe
# 189                                                NaN
# 190  International Monetary Fund, World Economic Ou...
#
#                                     Subject Descriptor         Units  Scale  \
# 0    Gross domestic product per capita, current prices  U.S. dollars  Units
# 1    Gross domestic product per capita, current prices  U.S. dollars  Units
# 2    Gross domestic product per capita, current prices  U.S. dollars  Units
# 3    Gross domestic product per capita, current prices  U.S. dollars  Units
# 4    Gross domestic product per capita, current prices  U.S. dollars  Units
# ..                                                 ...           ...    ...
# 186  Gross domestic product per capita, current prices  U.S. dollars  Units
# 187  Gross domestic product per capita, current prices  U.S. dollars  Units
# 188  Gross domestic product per capita, current prices  U.S. dollars  Units
# 189                                                NaN           NaN    NaN
# 190                                                NaN           NaN    NaN
#
#                          Country/Series-specific Notes       2015  \
# 0    See notes for:  Gross domestic product, curren...    599.994
# 1    See notes for:  Gross domestic product, curren...   3995.380
# 2    See notes for:  Gross domestic product, curren...   4318.140
# 3    See notes for:  Gross domestic product, curren...   4100.320
# 4    See notes for:  Gross domestic product, curren...  14414.300
# ..                                                 ...        ...
# 186  See notes for:  Gross domestic product, curren...   1302.940
# 187  See notes for:  Gross domestic product, curren...   1350.150
# 188  See notes for:  Gross domestic product, curren...   1064.350
# 189                                                NaN        NaN
# 190                                                NaN        NaN
#
#      Estimates Start After
# 0                   2013.0
# 1                   2010.0
# 2                   2014.0
# 3                   2014.0
# 4                   2011.0
# ..                     ...
# 186                 2008.0
# 187                 2010.0
# 188                 2012.0
# 189                    NaN
# 190                    NaN
#
# [191 rows x 7 columns]
#                      GDP per capita
# Country
# Albania                     3995.38
# Algeria                     4318.14
# Angola                      4100.32
# Antigua and Barbuda        14414.30
# Argentina                  13588.85

# %%
bli["Life satisfaction"].head()
# Out:
# Country
# Australia    7.3
# Austria      7.0
# Belgium      6.9
# Brazil       6.6
# Canada       7.3
# Name: Life satisfaction, dtype: float64

# %% [markdown]
# # Merge/Join dataset

# %%
df = pd.merge(left = weo, right = bli, left_index=True, right_index=True)
df.sort_values(by="GDP per capita", inplace=True)
df.head()
# Out:
#               GDP per capita  Air pollution  \
# Country
# South Africa         5694.57           22.0
# Brazil               8670.00           10.0
# Mexico               9009.28           16.0
# Russia               9054.91           15.0
# Turkey               9437.37           20.0
#
#               Dwellings without basic facilities  Educational attainment  \
# Country
# South Africa                                37.0                    43.0
# Brazil                                       6.7                    49.0
# Mexico                                       4.2                    37.0
# Russia                                      13.8                    95.0
# Turkey                                       6.5                    39.0
#
#               Employees working very long hours  Employment rate  \
# Country
# South Africa                              18.68             43.0
# Brazil                                     7.15             64.0
# Mexico                                    29.48             61.0
# Russia                                     0.16             70.0
# Turkey                                    33.77             51.0
#
#               Feeling safe walking alone at night  Homicide rate  \
# Country
# South Africa                                 36.1           10.0
# Brazil                                       37.3           27.6
# Mexico                                       45.9           17.9
# Russia                                       52.2           11.3
# Turkey                                       60.6            1.7
#
#               Household net adjusted disposable income  \
# Country
# South Africa                                   10872.0
# Brazil                                         12227.0
# Mexico                                         13891.0
# Russia                                         16657.0
# Turkey                                         17067.0
#
#               Household net financial wealth  ...  Personal earnings  \
# Country                                       ...
# South Africa                         17042.0  ...            11554.0
# Brazil                                7102.0  ...            14024.0
# Mexico                                4750.0  ...            15311.0
# Russia                                2260.0  ...            22101.0
# Turkey                                4429.0  ...            22848.0
#
#               Quality of support network  Rooms per person  \
# Country
# South Africa                        88.0               0.7
# Brazil                              90.0               0.8
# Mexico                              80.0               1.0
# Russia                              90.0               1.0
# Turkey                              86.0               1.0
#
#               Self-reported health  \
# Country
# South Africa                  67.0
# Brazil                        70.0
# Mexico                        66.0
# Russia                        43.0
# Turkey                        66.0
#
#               Stakeholder engagement for developing regulations  \
# Country
# South Africa                                                1.6
# Brazil                                                      2.2
# Mexico                                                      3.5
# Russia                                                      0.8
# Turkey                                                      2.1
#
#               Student skills  Time devoted to leisure and personal care  \
# Country
# South Africa           391.0                                      14.73
# Brazil                 395.0                                      14.45
# Mexico                 416.0                                      12.74
# Russia                 492.0                                      14.90
# Turkey                 425.0                                      12.59
#
#               Voter turnout  Water quality  Years in education
# Country
# South Africa           73.0           69.0                15.3
# Brazil                 79.0           72.0                15.9
# Mexico                 63.0           67.0                14.8
# Russia                 65.0           54.0                16.1
# Turkey                 85.0           63.0                17.9
#
# [5 rows x 25 columns]

# %%
test_indices = [0, 1, 6, 8, 33, 34, 35]
train_indices = list(set(range(36)) - set(test_indices))

train = df[["Air pollution", 'Life satisfaction']].iloc[train_indices]
test = df[["Air pollution", 'Life satisfaction']].iloc[test_indices]

# %%
test
# Out:
#                Air pollution  Life satisfaction
# Country
# South Africa            22.0                4.8
# Brazil                  10.0                6.6
# Poland                  22.0                6.0
# Latvia                  11.0                5.9
# Denmark                  9.0                7.5
# United States           10.0                6.9
# Norway                   5.0                7.5

# %%
# Code example
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import SGDRegressor
# Prepare the data
X = np.c_[train["Air pollution"]]
y = np.c_[train["Life satisfaction"]]

# Visualize the data
#df.plot(kind='scatter', x="GDP per capita", y='Life satisfaction')
#plt.show()

# Build a LinearRegression model
model_NormalEquation= ....

# Build a SGDRegressor model (keep maximum iteration at 300 and eta = 0.0001)
model_SGD = ....

# Make a prediction for Cyprus
X_new = [[18]]  # Cyprus' GDP per capita
print(model_NormalEquation.predict(X_new)) # outputs [[5.95199478]]
print(model_SGD.predict(X_new)) # outputs [[5.95199478]]

# %%
# Make a prediction for our test data
# Predict using your Normal Equation model
pred_NE = ....(test['Air pollution'].values.reshape(-1,1))

# Predit using your SGD model
pred_SGD = ...(test['Air pollution'].values.reshape(-1,1))
# Out:
#   File "/tmp/ipykernel_9439/1609387170.py", line 3
#     pred_NE = ....(test['Air pollution'].values.reshape(-1,1))
#                   ^
# SyntaxError: invalid syntax

# %%
pred_NE.ravel()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9439/2793465953.py in <cell line: 0>()
# ----> 1 pred_NE.ravel()
#
# NameError: name 'pred_NE' is not defined

# %%
pred_SGD
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9439/1098882394.py in <cell line: 0>()
# ----> 1 pred_SGD
#
# NameError: name 'pred_SGD' is not defined

# %%
from sklearn.metrics import mean_squared_error
# Fill in the blank and calculate the error
MAE_NE =mean_squared_error(test['Life satisfaction'] , ....)
MAE_NE
# Out:
#   File "/tmp/ipykernel_9439/2231708130.py", line 3
#     MAE_NE =mean_squared_error(test['Life satisfaction'] , ....)
#                                                                ^
# SyntaxError: invalid syntax

# %%
# Fill in the blank and calculate the error

MAE_SGD =mean_squared_error(test['Life satisfaction'] , ....)
MAE_SGD

# %% [markdown]
# # Discussion & Conclusions:
#
# Compare the results of M
# Perhaps this is a very synthetic dataset as the number of test data is 6 only. But, the purpose is that different algorithm works with different performanre and it is up to you to run different model for varied dataset and pick the best!
#
# As you know Normal Equation is mathematically finding global minimum and is always more succseful than SGD (when dataset is snall enough) which is randomly trying to find global minimal.
